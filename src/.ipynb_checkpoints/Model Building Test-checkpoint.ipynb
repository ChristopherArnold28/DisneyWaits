# %%
import pymysql
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import transformations
import config
# %matplotlib inline

# %%
conn = pymysql.connect(config.host, user=config.username,port=config.port,
                           passwd=config.password)

#gather all historical data to build model
RideWaits = pd.read_sql_query("call DisneyDB.RideWaitQuery('2,7,8,9')", conn)


starter_data = RideWaits.copy()

#transform data for model bulding
RideWaits = transformations.transformData(RideWaits)
# Out:
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])

# %%
RideWaits.head()

# %%
def create_dummies(df,column_name):
    dummies = pd.get_dummies(df[column_name],prefix=column_name)
    df = pd.concat([df,dummies],axis=1)
    df = df.drop([column_name], axis = 1)
    return df

def get_shift(day, steps):
    previous_steps = {}
    for i in range(1,1+steps):
        current_steps = []
        test_day_current = day.reset_index()
        for index,row in test_day_current.iterrows():
            if index in list(range(i)):
                current_steps.append(0)
            else:
                current_steps.append(test_day_current.loc[index - i,'Wait'])
        
        name = "previous_step"+str(i)
        previous_steps[name] = current_steps
    
    for key,value in previous_steps.items():
        day[key] = value
        
    return day
    
    
def shift_data(ride_data, shift_range):
    new_data_frame = pd.DataFrame()
    distinct_rides = list(ride_data['RideId'].unique())
    for ride in distinct_rides:
        this_ride = ride_data[ride_data['RideId'] == ride]
        day_list = list(this_ride['Date'].unique())
        for day in day_list:
            day_data = this_ride[this_ride['Date'] == day]
            new_data = get_shift(day_data, shift_range)
            new_data_frame = pd.concat([new_data_frame, new_data])

    return new_data_frame

def model_transformation(data, num_shifts, start_day = True, by_ride = True):
    ride_waits = data
    
    if by_ride:
        important_columns = ['Wait','DayOfWeek','Weekend','inEMH','EMHDay','MagicHourType','Month','TimeSinceOpen','TimeSinceMidday','MinutesSinceOpen']
        dummy_columns = ['DayOfWeek','Weekend','inEMH','EMHDay','MagicHourType','Month']
    else:
        important_columns = ['RideId','Date', 'Wait','Name','Tier','Location','IntellectualProp','ParkId','DayOfWeek','Weekend','CharacterExperience','inEMH','EMHDay','TimeSinceOpen','TimeSinceMidday','MagicHourType','MinutesSinceOpen','Month']
        ride_waits = ride_waits[ride_waits['Location'] != ""]
        dummy_columns = ['RideId','Tier','Location','IntellectualProp','ParkId','DayOfWeek','Weekend','CharacterExperience','inEMH','EMHDay','MagicHourType','Month']
        ride_waits = ride_waits.drop(['Name'], axis = 1)
    ride_waits = ride_waits[important_columns]
    ride_waits = ride_waits.dropna(how = "any")
    
    if start_day == False:
        ride_waits = shift_data(ride_waits,num_shifts)
    
    for column in dummy_columns:
        ride_waits = create_dummies(ride_waits, column)
        
    correlation = ride_waits.corr()['Wait']
    key_correlations = correlation[abs(correlation) > .005]
    important_cols = list(key_correlations.index)
    shift_columns = []
    if start_day == False:
        shift_columns = ["previous_step" + str(x+1)  for x in range(num_shifts)]
    important_cols = important_cols + ["Wait","MinutesSinceOpen"] + shift_columns
    important_cols = [x for x in important_cols if x != "Weekend_0"]
    important_cols = list(set(important_cols))
    ride_waits_key = ride_waits[important_cols]
    
    
    return ride_waits_key



def new_data_transform(data, num_shifts, important_cols, start_day = True, by_ride = True):
    ride_waits = data
    
    if by_ride:
        important_columns = ['Wait','DayOfWeek','Weekend','inEMH','EMHDay','MagicHourType','Month','TimeSinceOpen','TimeSinceMidday','MinutesSinceOpen']
        dummy_columns = ['DayOfWeek','Weekend','inEMH','EMHDay','MagicHourType','Month']
    else:
        important_columns = ['RideId','Date', 'Wait','Name','Tier','Location','IntellectualProp','ParkId','DayOfWeek','Weekend','CharacterExperience','inEMH','EMHDay','TimeSinceOpen','TimeSinceMidday','MagicHourType','MinutesSinceOpen','Month']
        ride_waits = ride_waits[ride_waits['Location'] != ""]
        dummy_columns = ['RideId','Tier','Location','IntellectualProp','ParkId','DayOfWeek','Weekend','CharacterExperience','inEMH','EMHDay','MagicHourType','Month']
        ride_waits = ride_waits.drop(['Name'], axis = 1)
    

    ride_waits = ride_waits[important_columns]
    
    ride_waits = ride_waits.dropna(how = "any")
    
    if start_day == False:
        ride_waits = shift_data(ride_waits,num_shifts)
    for column in dummy_columns:
        ride_waits = create_dummies(ride_waits, column)
        
    missing_cols = [x for x in important_cols if x not in ride_waits.columns]
    for col in missing_cols:
        ride_waits[col] = 0
        
    return ride_waits

# %%
from datetime import datetime
from pytz import timezone
tz = timezone('US/Eastern')
dtime = datetime.now(tz)
dtime = dtime.replace(hour = 7,minute = 0, second = 0, microsecond = 0)
date = dtime.date()
time = dtime.time().strftime("%H:%M")
from datetime import datetime
from dateutil.relativedelta import relativedelta

def date_range(start_date, end_date, increment, period):
    result = []
    nxt = start_date
    delta = relativedelta(**{period:increment})
    while nxt <= end_date:
        result.append(nxt)
        nxt += delta
    return result

end_time = dtime.replace(hour = 23, minute = 45, second = 0, microsecond = 0)
time_list = date_range(dtime, end_time, 15, 'minutes')
time_list = [x.time().strftime("%H:%M") for x in time_list]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
best_params = {'criterion': 'mse',
 'max_depth': 10,
 'max_features': 'auto',
 'min_samples_leaf': 5,
 'min_samples_split': 2,
 'n_estimators': 100}

rides = list(set(starter_data['Name']))
global todays_predictions
todays_predictions = {}

# %%
def make_daily_prediction(current_ride,ride, time_list, best_params, todays_predictions):
    ride_predictions = {}
    current_ride_fm = current_ride.copy()
    current_ride_fm = transformations.transformData(current_ride_fm)
    #print(current_ride.shape[0])
    #print(current_ride.columns)
    model_data = model_transformation(current_ride_fm, 1)
    important_columns = [x for x in model_data.columns if x != "Wait"]
    clf = RandomForestRegressor(**best_params)
    #scores = cross_val_score(clf, model_data[important_columns],model_data['Wait'], scoring = "neg_median_absolute_error", cv = 3)
    #ride_score = scores.mean()
    #ride_predictions['score'] = ride_score
    #print(model_data.head())
    clf.fit(model_data[important_columns], model_data['Wait'])
    predictions_frame = pd.DataFrame()
    ride_starter = current_ride.iloc[[0]]
    
    predictions_frame = pd.concat([ride_starter]*len(time_list),ignore_index = True)
    predictions_frame['Time'] = time_list
    predictions_frame = transformations.transformData(predictions_frame)
    # print(predictions_frame)
    #predictions_frame = transformations.transformData(predictions_frame)
    model_predictions_frame = new_data_transform(predictions_frame, 3, important_columns)
    predictions_frame['predicted_wait'] = clf.predict(model_predictions_frame[important_columns])
    
    
#     for time in time_list:
#         ride_starter['Time'] = time
#         row_data = ride_starter.copy()
#         #print(row_data)
#         try:
#             row_data = transformations.transformData(row_data)
#         except:
#             continue
#         #print(row_data)
#         predictions_frame = pd.concat([predictions_frame,row_data])
#         #print(predictions_frame.iloc[[predictions_frame.shape[0]-1]])
#         model_predictions_frame = new_data_transform(predictions_frame,3, important_columns)
#         predictions_frame['Wait'] = clf.predict(model_predictions_frame[important_columns])
#         #print(predictions_frame)
    
    ride_predictions['predictions'] = predictions_frame
    todays_predictions[ride] = ride_predictions

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
best_params = {'criterion': 'mse',
 'max_depth': 10,
 'max_features': 'auto',
 'min_samples_leaf': 5,
 'min_samples_split': 2,
 'n_estimators': 100}

rides = list(set(starter_data['Name']))
global todays_predictions
todays_predictions = {}

import threading
num_threads = len(rides)

threads = []
for i in range(num_threads):
    print(rides[i-1])
    ride = rides[i-1]
    current_ride = starter_data.copy()
    current_ride = starter_data[current_ride['Name'] == ride]
    process = threading.Thread(target = make_daily_prediction, args = [current_ride,ride,time_list, best_params, todays_predictions])
    process.start()
    threads.append(process)

for process in threads:
    process.join()
# Out:
# Swiss Family Treehouse
# Meet Chewbacca at Star Wars Launch Bay
# Seven Dwarfs Mine Train
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# The Haunted Mansion
# A Pirates Adventure ~ Treasures of the Seven Seas
# Navi River Journey
# Star Wars Launch Bay Theater
# Buzz Lightyears Space Ranger Spin
# Meet Cinderella and Elena at Princess Fairytale Hall
# Tom Sawyer Island
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Meet Disney Pals at the Epcot Character Spot
# Meet Rapunzel and Tiana at Princess Fairytale Hall
# Expedition Everest - Legend of the Forbidden Mountain
# Meet Magnifique Disney Friends as Circus Stars at Petes Silly Sideshow
# Meet Daring Disney Pals as Circus Stars at Petes Silly Sideshow
# Mad Tea Party
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# The Twilight Zone Tower of Terror
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Alien Swirling Saucers
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Walt Disneys Enchanted Tiki Room
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# Enchanted Tales with Belle
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# TriceraTop Spin
# Kilimanjaro Safaris
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Mission: SPACE
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Rock n Roller Coaster Starring Aerosmith
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Monsters, Inc. Laugh Floor
# The Barnstormer
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Muppet*Vision 3D
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# Meet Mickey Mouse at Town Square Theater
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Toy Story Mania!
# Meet Favorite Disney Pals at Adventurers Outpost
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# Meet Anna and Elsa at Royal Sommerhus
# Star Tours- The Adventures Continue
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# Its Tough to be a Bug!
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Peter Pans Flight
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Walt Disneys Carousel of Progress
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Royal Sommerhus
# The Magic Carpets of Aladdin
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# BB-8 Astromech on Duty
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Spaceship Earth
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Avatar Flight of Passage
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Soarin
# Big Thunder Mountain Railroad
# Celebrity Spotlight
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# Test Track
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# ...
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# The Hall of Presidents
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["Month"] = RideWaits["Date"].dt.month
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["MagicHourType"] = pd.Categorical(RideWaits["MagicHourType"])
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["TimeSinceRideOpen"] = (RideWaits["Date"] - RideWaits["OpeningDate"]).dt.days
# C:\Users\Chrisrtopher\Documents\DisneyWaits\src\transformations.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   RideWaits["DayOfWeek"] = pd.Categorical(RideWaits["DayOfWeek"])
# Wall time: 1min 18s

# %%
metric = []
for key, value in todays_predictions.items():
    print(str(key) + " : " + str(value['predictions'].shape[0]))
# Out:
# A Pirates Adventure ~ Treasures of the Seven Seas : 55
# Star Wars Launch Bay Theater : 43
# Tom Sawyer Island : 47
# Walt Disneys Enchanted Tiki Room : 55
# Swiss Family Treehouse : 54
# Walt Disneys Carousel of Progress : 55
# Royal Sommerhus : 47
# The Hall of Presidents : 55
# TriceraTop Spin : 43
# Navi River Journey : 43
# The Haunted Mansion : 54
# Seven Dwarfs Mine Train : 54
# Kilimanjaro Safaris : 43
# Meet Chewbacca at Star Wars Launch Bay : 43
# Meet Daring Disney Pals as Circus Stars at Petes Silly Sideshow : 54
# Buzz Lightyears Space Ranger Spin : 54
# Meet Cinderella and Elena at Princess Fairytale Hall : 54
# Expedition Everest - Legend of the Forbidden Mountain : 43
# Meet Rapunzel and Tiana at Princess Fairytale Hall : 54
# Meet Disney Pals at the Epcot Character Spot : 47
# Meet Magnifique Disney Friends as Circus Stars at Petes Silly Sideshow : 54
# Mad Tea Party : 54
# Alien Swirling Saucers : 43
# Rock n Roller Coaster Starring Aerosmith : 43
# Mission: SPACE : 47
# The Barnstormer : 54
# The Twilight Zone Tower of Terror : 43
# Muppet*Vision 3D : 43
# Toy Story Mania! : 43
# The Magic Carpets of Aladdin : 54
# Meet Favorite Disney Pals at Adventurers Outpost : 43
# Meet Mickey Mouse at Town Square Theater : 54
# Enchanted Tales with Belle : 54
# Monsters, Inc. Laugh Floor : 54
# Star Tours- The Adventures Continue : 43
# Peter Pans Flight : 54
# Its Tough to be a Bug! : 43
# BB-8 Astromech on Duty : 43
# Kali River Rapids : 43
# Meet Anna and Elsa at Royal Sommerhus : 47
# Gran Fiesta Tour Starring The Three Caballeros : 47
# Soarin : 47
# Test Track : 47
# Big Thunder Mountain Railroad : 54
# Avatar Flight of Passage : 43
# Living with the Land : 47
# Celebrity Spotlight : 43
# Primeval Whirl : 43
# Pirates of the Caribbean : 54
# Meet Ariel at Her Grotto : 54
# Journey Into Imagination With Figment : 47
# its a small world : 54
# Splash Mountain : 54
# Space Mountain : 54
# Spaceship Earth : 47
# Tomorrowland Speedway : 54
# Mickeys PhilharMagic : 54
# Prince Charming Regal Carrousel : 54
# Slinky Dog Dash : 43
# Meet Tinker Bell at Town Square Theater : 54
# Frozen Ever After : 47
# The Seas with Nemo and Friends : 47
# Mickey and Minnie Starring in Red Carpet Dreams : 43
# Under the Sea ~ Journey of The Little Mermaid : 54
# Turtle Talk With Crush : 47
# Star Wars Launch Bay: Encounter Kylo Ren : 43
# The Many Adventures of Winnie the Pooh : 54
# Jungle Cruise : 54
# DINOSAUR : 43
# Dumbo the Flying Elephant : 54
# Astro Orbiter : 54

# %%
todays_predictions['Seven Dwarfs Mine Train']['predictions']
# Out:
#       RideId       Date      Time  Wait                     Name OpeningDate  \
# 9   16767284 2018-09-19  09:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 10  16767284 2018-09-19  09:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 11  16767284 2018-09-19  09:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 12  16767284 2018-09-19  10:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 13  16767284 2018-09-19  10:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 14  16767284 2018-09-19  10:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 15  16767284 2018-09-19  10:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 16  16767284 2018-09-19  11:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 17  16767284 2018-09-19  11:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 18  16767284 2018-09-19  11:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 19  16767284 2018-09-19  11:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 20  16767284 2018-09-19  12:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 21  16767284 2018-09-19  12:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 22  16767284 2018-09-19  12:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 23  16767284 2018-09-19  12:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 24  16767284 2018-09-19  13:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 25  16767284 2018-09-19  13:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 26  16767284 2018-09-19  13:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 27  16767284 2018-09-19  13:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 28  16767284 2018-09-19  14:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 29  16767284 2018-09-19  14:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 30  16767284 2018-09-19  14:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 31  16767284 2018-09-19  14:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 32  16767284 2018-09-19  15:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 33  16767284 2018-09-19  15:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 34  16767284 2018-09-19  15:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 35  16767284 2018-09-19  15:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 36  16767284 2018-09-19  16:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 37  16767284 2018-09-19  16:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 38  16767284 2018-09-19  16:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 39  16767284 2018-09-19  16:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 40  16767284 2018-09-19  17:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 41  16767284 2018-09-19  17:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 42  16767284 2018-09-19  17:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 43  16767284 2018-09-19  17:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 44  16767284 2018-09-19  18:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 45  16767284 2018-09-19  18:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 46  16767284 2018-09-19  18:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 47  16767284 2018-09-19  18:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 48  16767284 2018-09-19  19:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 49  16767284 2018-09-19  19:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 50  16767284 2018-09-19  19:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 51  16767284 2018-09-19  19:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 52  16767284 2018-09-19  20:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 53  16767284 2018-09-19  20:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 54  16767284 2018-09-19  20:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 55  16767284 2018-09-19  20:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 57  16767284 2018-09-19  21:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 58  16767284 2018-09-19  21:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 59  16767284 2018-09-19  21:45:00    65  Seven Dwarfs Mine Train  2014-05-28
# 60  16767284 2018-09-19  22:00:00    65  Seven Dwarfs Mine Train  2014-05-28
# 61  16767284 2018-09-19  22:15:00    65  Seven Dwarfs Mine Train  2014-05-28
# 62  16767284 2018-09-19  22:30:00    65  Seven Dwarfs Mine Train  2014-05-28
# 63  16767284 2018-09-19  22:45:00    65  Seven Dwarfs Mine Train  2014-05-28
#
#                 Tier     Location IntellectualProp ParkId       ...        \
# 9   major_attraction  Fantasyland         Princess      7       ...
# 10  major_attraction  Fantasyland         Princess      7       ...
# 11  major_attraction  Fantasyland         Princess      7       ...
# 12  major_attraction  Fantasyland         Princess      7       ...
# 13  major_attraction  Fantasyland         Princess      7       ...
# 14  major_attraction  Fantasyland         Princess      7       ...
# 15  major_attraction  Fantasyland         Princess      7       ...
# 16  major_attraction  Fantasyland         Princess      7       ...
# 17  major_attraction  Fantasyland         Princess      7       ...
# 18  major_attraction  Fantasyland         Princess      7       ...
# 19  major_attraction  Fantasyland         Princess      7       ...
# 20  major_attraction  Fantasyland         Princess      7       ...
# 21  major_attraction  Fantasyland         Princess      7       ...
# 22  major_attraction  Fantasyland         Princess      7       ...
# 23  major_attraction  Fantasyland         Princess      7       ...
# 24  major_attraction  Fantasyland         Princess      7       ...
# 25  major_attraction  Fantasyland         Princess      7       ...
# 26  major_attraction  Fantasyland         Princess      7       ...
# 27  major_attraction  Fantasyland         Princess      7       ...
# 28  major_attraction  Fantasyland         Princess      7       ...
# 29  major_attraction  Fantasyland         Princess      7       ...
# 30  major_attraction  Fantasyland         Princess      7       ...
# 31  major_attraction  Fantasyland         Princess      7       ...
# 32  major_attraction  Fantasyland         Princess      7       ...
# 33  major_attraction  Fantasyland         Princess      7       ...
# 34  major_attraction  Fantasyland         Princess      7       ...
# 35  major_attraction  Fantasyland         Princess      7       ...
# 36  major_attraction  Fantasyland         Princess      7       ...
# 37  major_attraction  Fantasyland         Princess      7       ...
# 38  major_attraction  Fantasyland         Princess      7       ...
# 39  major_attraction  Fantasyland         Princess      7       ...
# 40  major_attraction  Fantasyland         Princess      7       ...
# 41  major_attraction  Fantasyland         Princess      7       ...
# 42  major_attraction  Fantasyland         Princess      7       ...
# 43  major_attraction  Fantasyland         Princess      7       ...
# 44  major_attraction  Fantasyland         Princess      7       ...
# 45  major_attraction  Fantasyland         Princess      7       ...
# 46  major_attraction  Fantasyland         Princess      7       ...
# 47  major_attraction  Fantasyland         Princess      7       ...
# 48  major_attraction  Fantasyland         Princess      7       ...
# 49  major_attraction  Fantasyland         Princess      7       ...
# 50  major_attraction  Fantasyland         Princess      7       ...
# 51  major_attraction  Fantasyland         Princess      7       ...
# 52  major_attraction  Fantasyland         Princess      7       ...
# 53  major_attraction  Fantasyland         Princess      7       ...
# 54  major_attraction  Fantasyland         Princess      7       ...
# 55  major_attraction  Fantasyland         Princess      7       ...
# 57  major_attraction  Fantasyland         Princess      7       ...
# 58  major_attraction  Fantasyland         Princess      7       ...
# 59  major_attraction  Fantasyland         Princess      7       ...
# 60  major_attraction  Fantasyland         Princess      7       ...
# 61  major_attraction  Fantasyland         Princess      7       ...
# 62  major_attraction  Fantasyland         Princess      7       ...
# 63  major_attraction  Fantasyland         Princess      7       ...
#
#    inEMH validTime EMHDay TimeSinceOpen TimeSinceMidday MagicHourType  \
# 9      0         1      1             0               5         Night
# 10     0         1      1             0               5         Night
# 11     0         1      1             0               5         Night
# 12     0         1      1             1               4         Night
# 13     0         1      1             1               4         Night
# 14     0         1      1             1               4         Night
# 15     0         1      1             1               4         Night
# 16     0         1      1             2               3         Night
# 17     0         1      1             2               3         Night
# 18     0         1      1             2               3         Night
# 19     0         1      1             2               3         Night
# 20     0         1      1             3               2         Night
# 21     0         1      1             3               2         Night
# 22     0         1      1             3               2         Night
# 23     0         1      1             3               2         Night
# 24     0         1      1             4               1         Night
# 25     0         1      1             4               1         Night
# 26     0         1      1             4               1         Night
# 27     0         1      1             4               1         Night
# 28     0         1      1             5               0         Night
# 29     0         1      1             5               0         Night
# 30     0         1      1             5               0         Night
# 31     0         1      1             5               0         Night
# 32     0         1      1             6               1         Night
# 33     0         1      1             6               1         Night
# 34     0         1      1             6               1         Night
# 35     0         1      1             6               1         Night
# 36     0         1      1             7               2         Night
# 37     0         1      1             7               2         Night
# 38     0         1      1             7               2         Night
# 39     0         1      1             7               2         Night
# 40     0         1      1             8               3         Night
# 41     0         1      1             8               3         Night
# 42     0         1      1             8               3         Night
# 43     0         1      1             8               3         Night
# 44     0         1      1             9               4         Night
# 45     0         1      1             9               4         Night
# 46     0         1      1             9               4         Night
# 47     0         1      1             9               4         Night
# 48     0         1      1            10               5         Night
# 49     0         1      1            10               5         Night
# 50     0         1      1            10               5         Night
# 51     0         1      1            10               5         Night
# 52     0         1      1            11               6         Night
# 53     0         1      1            11               6         Night
# 54     0         1      1            11               6         Night
# 55     0         1      1            11               6         Night
# 57     1         1      1            12               7         Night
# 58     1         1      1            12               7         Night
# 59     1         1      1            12               7         Night
# 60     1         1      1            13               8         Night
# 61     1         1      1            13               8         Night
# 62     1         1      1            13               8         Night
# 63     1         1      1            13               8         Night
#
#     MinutesSinceOpen  Month  TimeSinceRideOpen  predicted_wait
# 9               15.0      9               1575       70.723375
# 10              30.0      9               1575       71.448290
# 11              45.0      9               1575       71.721017
# 12              60.0      9               1575       77.611993
# 13              75.0      9               1575       77.143187
# 14              90.0      9               1575       77.085589
# 15             105.0      9               1575       78.129470
# 16             120.0      9               1575       71.237788
# 17             135.0      9               1575       70.655940
# 18             150.0      9               1575       70.574392
# 19             165.0      9               1575       70.574392
# 20             180.0      9               1575       70.493701
# 21             195.0      9               1575       70.528484
# 22             210.0      9               1575       70.914896
# 23             225.0      9               1575       70.939959
# 24             240.0      9               1575       73.329394
# 25             255.0      9               1575       73.523484
# 26             270.0      9               1575       73.367962
# 27             285.0      9               1575       73.651586
# 28             300.0      9               1575       73.830833
# 29             315.0      9               1575       76.570664
# 30             330.0      9               1575       76.612432
# 31             345.0      9               1575       81.843533
# 32             360.0      9               1575       83.724595
# 33             375.0      9               1575       84.206301
# 34             390.0      9               1575       82.474641
# 35             405.0      9               1575       76.250890
# 36             420.0      9               1575       72.388242
# 37             435.0      9               1575       72.395835
# 38             450.0      9               1575       72.664966
# 39             465.0      9               1575       72.358310
# 40             480.0      9               1575       74.049784
# 41             495.0      9               1575       82.787292
# 42             510.0      9               1575       84.887250
# 43             525.0      9               1575       85.354367
# 44             540.0      9               1575       79.843095
# 45             555.0      9               1575       78.867606
# 46             570.0      9               1575       78.531859
# 47             585.0      9               1575       78.531859
# 48             600.0      9               1575       79.049143
# 49             615.0      9               1575       79.049143
# 50             630.0      9               1575       78.343705
# 51             645.0      9               1575       76.071486
# 52             660.0      9               1575       46.532703
# 53             675.0      9               1575       46.945912
# 54             690.0      9               1575       45.173277
# 55             705.0      9               1575       49.970017
# 57             735.0      9               1575       51.389075
# 58             750.0      9               1575       51.156085
# 59             765.0      9               1575       43.685936
# 60             780.0      9               1575       42.928694
# 61             795.0      9               1575       41.087993
# 62             810.0      9               1575       39.184205
# 63             825.0      9               1575       39.184205
#
# [54 rows x 28 columns]

# %%
all_predictions = pd.DataFrame()
for key,value in todays_predictions.items():
    current_frame = value['predictions']
    current_frame = current_frame[['RideId','Time','predicted_wait']]
    current_frame.columns = ['RideId','Time','PredictedWait']
    current_frame['PredictedWait'] = [int(str(x).split(".")[0]) for x in current_frame['PredictedWait']]
    all_predictions = pd.concat([all_predictions, current_frame])
# Out:
# C:\Users\Chrisrtopher\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cur = conn.cursor()
for index,row in all_predictions.iterrows():
    query = "insert into DisneyDB.Ride_Waits_Today_Predicted (RideId, Time, PredictedWait) values (%i, '%s', %i)" %(row['RideId'], row['Time'], row['PredictedWait'])
    cur.execute(query)
    conn.commit()
